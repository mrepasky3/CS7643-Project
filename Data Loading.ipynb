# %%
import torch
import torchvision
import torchvision.datasets as datasets
import matplotlib.pyplot as plt
import dataset_prep

# %% [markdown]
# # Toy

# %%
set_loader = dataset_prep.SetsToy(max_size=4,fixed_size=True)
train_d, train_l, test_d, test_l = set_loader.sum_task()

# %%
num = torch.randint(train_l.shape[0],(1,))
print(train_l[num])
print(train_d[num])
# Out:
# tensor([11], dtype=torch.int32)
# tensor([3, 2, 5, 1])

# %% [markdown]
# # MNIST

# %%
set_loader = dataset_prep.SetsMNIST(max_size=4,fixed_size=True)
train_d, train_l, test_d, test_l = set_loader.sum_task()
# Out:
# C:\Users\Matt\anaconda3\lib\site-packages\torchvision\datasets\mnist.py:62: UserWarning: train_data has been renamed data
#   warnings.warn("train_data has been renamed data")
# C:\Users\Matt\anaconda3\lib\site-packages\torchvision\datasets\mnist.py:52: UserWarning: train_labels has been renamed targets
#   warnings.warn("train_labels has been renamed targets")

# %%
num = torch.randint(train_l.shape[0],(1,))
print(train_l[num])
for i in range(len(train_d[num])):
    fig = plt.figure(figsize=(1,1))
    plt.imshow(train_d[num][i])
    plt.show()
# Out:
# tensor([8], dtype=torch.int32)

# %% [markdown]
# # Omniglot

# %%
set_loader = dataset_prep.SetsOmniglot(max_size=40,fixed_size=True)
train_d, train_l, test_d, test_l = set_loader.unique_task()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
num = torch.randint(train_l.shape[0],(1,))
print(train_l[num],len(train_d[num]))
for i in range(len(train_d[num])):
    fig = plt.figure(figsize=(1,1))
    plt.imshow(train_d[num][i][0])
    plt.show()
# Out:
# tensor([40], dtype=torch.int32) 40
